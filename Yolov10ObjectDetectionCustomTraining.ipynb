# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 2. Prepare data ###

# !scp '/content/gdrive/My Drive/University of Victoria/Entrepreneurial Co-op/Computer Vision/data.zip' '/content/data.zip'

# !unzip '/content/data.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Tomato leaf diseases dataset for Object Detection/Dataset without augmentation/train/images/dark-brown-spots-with-concentric-rings_jpg.rf.df008f4cb968822268a5a781e93890e9.jpg
#   inflating: /content/Tomato leaf diseases dataset for Object Detection/Dataset without augmentation/train/images/download_jpg.rf.813e66dc250db6d234397e28e4abb0c3.jpg
#   inflating: /content/Tomato leaf diseases dataset for Object Detection/Dataset without augmentation/train/images/droppedImage_3-1_jpg.rf.9c6d47d1e95f27470e374f38f5a5be5f.jpg
#   inflating: /content/Tomato leaf diseases dataset for Object Detection/Dataset without augmentation/train/images/dscf2712_jpg.rf.151e6d8dea31cbc32d7a46e86dbf8f74.jpg
#   inflating: /content/Tomato leaf diseases dataset for Object Detection/Dataset without augmentation/train/images/dscn1652cropped_jpg.rf.12fddc9856cda9829383a22c1ce01065.jpg
# ...

# %%
### 3. Install packages ###

# !git clone https://github.com/THU-MIG/yolov10.git
# !cd yolov10 && pip install .

# Update ultralytics to the latest version from PyPI
# !pip install -U ultralytics
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20338, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 20338 (delta 2), reused 0 (delta 0), pack-reused 20334 (from 2)
# Receiving objects: 100% (20338/20338), 11.10 MiB | 24.66 MiB/s, done.
# Resolving deltas: 100% (14354/14354), done.
# Processing /content/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=732494 sha256=f4685c8932b5a29d9ba365abbb50ce8f0cda167562980e41de00c816af98d769
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_697ge30/wheels/6a/11/70/e412a19c4b42f8af8625bd9dd3f3056374a6079eeef6bd994f
# Successfully built ultralytics
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


config_path = '/content/Tomato leaf diseases dataset for Object Detection/Dataset without augmentation/data.yaml'

# Load a model
model = YOLO("jameslahm/yolov10n")  # load pre trained model

# Use the model
model.train(data=config_path, epochs=100, batch=32)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.70 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
### 5. Download results ###

from google.colab import files


# !zip -r /content/runs.zip /content/runs

files.download('/content/runs.zip')
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 10%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 10%)
#   adding: content/runs/detect/train/val_batch1_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/results.csv (deflated 63%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 15%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 8%)
#   adding: content/runs/detect/train/train_batch9182.jpg (deflated 6%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 2%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 2%)
# ...
