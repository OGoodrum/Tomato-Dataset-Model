# %%
import os
import pickle

from skimage.io import imread
from skimage.transform import resize
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# prepare data
input_dir = 'C:/Users/olive/OneDrive/Documents/Tomato Dataset/PlantVillage'
categories = ['Tomato__Target_Spot', 'Tomato__Tomato_mosaic_virus', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite']
IMAGE_EXTENSIONS = ('.jpg', '.jpeg', '.png')

data = []
labels = []
for category_idx, category in enumerate(categories):
    for file in os.listdir(os.path.join(input_dir, category)):
        if not file.lower().endswith(IMAGE_EXTENSIONS):
            continue
        img_path = os.path.join(input_dir, category, file)
        img = imread(img_path)
        img = resize(img, (15, 15))
        data.append(img.flatten())
        labels.append(category_idx)

data = np.asarray(data)
labels = np.asarray(labels)

# %%
# train / test split
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, stratify=labels)
print(x_train.shape, y_train.shape)
# Out:
# (12808, 675) (12808,)

# %%
# train classifier
classifier = SVC()

parameters = [{'gamma': [0.01, 0.001, 0.0001], 'C': [1, 10, 100, 1000]}]

grid_search = GridSearchCV(classifier, parameters, verbose=2)

grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ....................................C=1, gamma=0.01; total time=  49.8s
# [CV] END ....................................C=1, gamma=0.01; total time=  48.9s
# [CV] END ....................................C=1, gamma=0.01; total time=  49.3s
# [CV] END ....................................C=1, gamma=0.01; total time=  49.3s
# [CV] END ....................................C=1, gamma=0.01; total time=  49.6s
# [CV] END ...................................C=1, gamma=0.001; total time= 1.3min
# [CV] END ...................................C=1, gamma=0.001; total time= 1.2min
# [CV] END ...................................C=1, gamma=0.001; total time= 1.2min
# [CV] END ...................................C=1, gamma=0.001; total time= 1.4min
# [CV] END ...................................C=1, gamma=0.001; total time= 1.3min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.5min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.5min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.5min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.5min
# [CV] END ..................................C=1, gamma=0.0001; total time= 1.6min
# [CV] END ...................................C=10, gamma=0.01; total time=  32.0s
# [CV] END ...................................C=10, gamma=0.01; total time=  32.2s
# [CV] END ...................................C=10, gamma=0.01; total time=  30.3s
# [CV] END ...................................C=10, gamma=0.01; total time=  30.3s
# [CV] END ...................................C=10, gamma=0.01; total time=  30.4s
# [CV] END ..................................C=10, gamma=0.001; total time=  47.5s
# [CV] END ..................................C=10, gamma=0.001; total time=  47.4s
# [CV] END ..................................C=10, gamma=0.001; total time=  54.4s
# [CV] END ..................................C=10, gamma=0.001; total time=  51.2s
# [CV] END ..................................C=10, gamma=0.001; total time=  51.2s
# [CV] END .................................C=10, gamma=0.0001; total time= 1.3min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.3min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.3min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.4min
# [CV] END .................................C=10, gamma=0.0001; total time= 1.3min
# [CV] END ..................................C=100, gamma=0.01; total time=  28.1s
# [CV] END ..................................C=100, gamma=0.01; total time=  27.9s
# [CV] END ..................................C=100, gamma=0.01; total time=  28.0s
# [CV] END ..................................C=100, gamma=0.01; total time=  30.8s
# [CV] END ..................................C=100, gamma=0.01; total time=  28.4s
# [CV] END .................................C=100, gamma=0.001; total time=  35.9s
# [CV] END .................................C=100, gamma=0.001; total time=  34.9s
# [CV] END .................................C=100, gamma=0.001; total time=  34.9s
# [CV] END .................................C=100, gamma=0.001; total time=  35.0s
# [CV] END .................................C=100, gamma=0.001; total time=  34.4s
# [CV] END ................................C=100, gamma=0.0001; total time=  54.2s
# [CV] END ................................C=100, gamma=0.0001; total time=  52.2s
# [CV] END ................................C=100, gamma=0.0001; total time=  50.6s
# [CV] END ................................C=100, gamma=0.0001; total time=  49.1s
# [CV] END ................................C=100, gamma=0.0001; total time=  48.9s
# [CV] END .................................C=1000, gamma=0.01; total time=  26.6s
# [CV] END .................................C=1000, gamma=0.01; total time=  26.5s
# [CV] END .................................C=1000, gamma=0.01; total time=  26.7s
# [CV] END .................................C=1000, gamma=0.01; total time=  27.2s
# [CV] END .................................C=1000, gamma=0.01; total time=  27.3s
# [CV] END ................................C=1000, gamma=0.001; total time=  28.1s
# [CV] END ................................C=1000, gamma=0.001; total time=  28.0s
# [CV] END ................................C=1000, gamma=0.001; total time=  28.4s
# [CV] END ................................C=1000, gamma=0.001; total time=  28.2s
# [CV] END ................................C=1000, gamma=0.001; total time=  28.1s
# [CV] END ...............................C=1000, gamma=0.0001; total time=  33.8s
# [CV] END ...............................C=1000, gamma=0.0001; total time=  33.7s
# [CV] END ...............................C=1000, gamma=0.0001; total time=  33.7s
# [CV] END ...............................C=1000, gamma=0.0001; total time=  35.6s
# [CV] END ...............................C=1000, gamma=0.0001; total time=  34.2s
# GridSearchCV(estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'gamma': [0.01, 0.001, 0.0001]}],
#              verbose=2)

# %%
# test performance
best_estimator = grid_search.best_estimator_

y_prediction = best_estimator.predict(x_test)

score = accuracy_score(y_prediction, y_test)

print('{}% of samples were correctly classified'.format(str(score * 100)))

pickle.dump(best_estimator, open('./SVCModel.p', 'wb'))
# Out:
# 87.35560412113644% of samples were correctly classified

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_prediction, y_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=categories)
disp.plot()
plt.xticks(rotation=90)
plt.show()
